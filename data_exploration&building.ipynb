# %% [markdown]
# # The data

# %% [markdown]
# ### Question 1 data
#
# Based on the image provided, I'll build a csv file containing each element as data, as to represent each element from the example.
# This is the image used to create this data:
# <img src="./Contextualization/description-1.png" alt="Alternative text" />
#
# To transcribe these into actual code, I'll follow the following guidelines, as stated in the presentation of the assignment:
# 1. Number of cars per train (range of values is 3 to 5)
# 2. Amount of different loads it can carry (valor entre 1 a 4)
# 3. For each car of a train:
#     1. the quantity of axle with wheels (range of values is 2 to 3)
#     2. the length of a car (short or long)
#     3. the shape of the car body, and can be
#        1. Closed-rectangle,
#        2. open-rectangle
#        3. Double open-rectangle
#        4. Ellipse,
#        5. Engine or locomotive
#        6. Hexagon
#        7. Jagged top,
#        8. Open trap,
#        9. Sloped top
#     4. The number of loads (range of values is 0 to 3)
#     5. Shape of the load (circle, hexagon, rectangle, or triangle).
#
# Alongsides 10 boolean attributes which describe wether or not a pair of cargo types are in adjacent train cars (since each car carries a single type of cargo)
# We have the following relations with respect to the carriages of a train, whose logical value
# varies between -1 (False) and 1 (True).
# 1. There is a rectangle next to a rectangle (-1 or 1)
# 2. There is a rectangle next to a triangle (-1 or 1)
# 3. There is a rectangle next to a hexagon (-1 or 1)
# 4. There is a rectangle next to a circle (-1 or 1)
# 5. There is a triangle next to a triangle (-1 or 1)
# 6. There is a triangle next to a hexagon (-1 or 1)
# 7. There is a triangle next to a circle (-1 or 1)
# 8. There is a circle next to a circle (-1 or 1)
#
# I'll code each as a json, where:
# ```
# {
#     "train_id":{
#         "num_car":int,
#         "dif_loads":int,
#         "cars":{
#                 "car_id":{
#                     "num_wheels":int,
#                     "length":int,
#                     "shape":int,
#                     "num_load":int,
#                     "shape_load":int
#                 }
#             }
#         "rect2rect":int,
#         "rect2tri":int,
#         "rect2hex":int,
#         "rect2circ":int,
#         "tri2tri":int,
#         "tri2hex":int,
#         "tri2circ":int,
#         "circ2cir":int
#         }
#     }
# }
# ```

# %% [markdown]
# <img src="./Contextualization/description-1.png" alt="Alternative text" />

# %%
dataset = dict()
dataset['1'] = {
    "num_car": 5,
    "dif_loads": 4,
    "cars":{
        "1":{
            "num_wheels":2,
            "length": 1,
            "shape": 5,
            "num_load": 0,
            "shape_load": -1,
            "next_crc": -1,
            "next_hex": -1,
            "next_rect": 1,
            "next_tri":-1,
        },
        "2":{
            "num_wheels":2,
            "length": 1,
            "shape": 2,
            "num_load": 3,
            "shape_load": 2,
            "next_crc": -1,
            "next_hex": -1,
            "next_rect": -1,
            "next_tri": 1,
        },
        "3":{
            "num_wheels":2,
            "length": -1,
            "shape": 9,
            "num_load": 1,
            "shape_load": 4,
            "next_crc": -1,
            "next_hex": 1,
            "next_rect": -1,
            "next_tri":1,
        },
        "4":{
            "num_wheels":3,
            "length": 1,
            "shape": 2,
            "num_load": 1,
            "shape_load": 2,
            "next_crc": 1,
            "next_hex": -1,
            "next_rect": -1,
            "next_tri":1,
        },
        "5":{
            "num_wheels":2,
            "length": -1,
            "shape": 2,
            "num_load": 1,
            "shape_load": 1,
            "next_crc": -1,
            "next_hex": 1,
            "next_rect": -1,
            "next_tri":-1,
        },
    },
    "rect2rect":-1,
    "rect2tri":1,
    "rect2hex":-1,
    "rect2circ":-1,
    "tri2tri":-1,
    "tri2hex":1,
    "tri2circ":-1,
    "circ2cir":-1,
    "east":1
}
dataset['2'] = {
    "num_car": 4,
    "dif_loads": 3,
    "cars":{
        "1":{
            "num_wheels":2,
            "length": 1,
            "shape": 5,
            "num_load": 0,
            "shape_load": -1,
            "next_crc": -1,
            "next_hex": -1,
            "next_rect": -1,
            "next_tri":1,
        },
        "2":{
            "num_wheels":2,
            "length": -1,
            "shape": 2,
            "num_load": 1,
            "shape_load": 4,
            "next_crc": -1,
            "next_hex": -1,
            "next_rect": 1,
            "next_tri":-1,
        },
        "3":{
            "num_wheels":2,
            "length": -1,
            "shape": 8,
            "num_load": 1,
            "shape_load": 3,
            "next_crc": 1,
            "next_hex": -1,
            "next_rect": -1,
            "next_tri":1,
        },
        "4":{
            "num_wheels":2,
            "length": -1,
            "shape": 1,
            "num_load": 2,
            "shape_load": 1,
            "next_crc": -1,
            "next_hex": -1,
            "next_rect": 1,
            "next_tri":-1,
        },
    },
    "rect2rect":-1,
    "rect2tri":1,
    "rect2hex":-1,
    "rect2circ":1,
    "tri2tri":-1,
    "tri2hex":-1,
    "tri2circ":-1,
    "circ2cir":-1,
    "east":1
}
dataset['3'] = {
    "num_car": 4,
    "dif_loads": 2,
    "cars":{
        "1":{
            "num_wheels":2,
            "length": 1,
            "shape": 5,
            "num_load": 0,
            "shape_load": -1,
            "next_crc": 1,
            "next_hex": -1,
            "next_rect": -1,
            "next_tri":-1,
        },
        "2":{
            "num_wheels":2,
            "length": -1,
            "shape": 2,
            "num_load": 1,
            "shape_load": 1,
            "next_crc": -1,
            "next_hex": -1,
            "next_rect": -1,
            "next_tri":1,
        },
        "3":{
            "num_wheels":2,
            "length": -1,
            "shape": 6,
            "num_load": 1,
            "shape_load": 4,
            "next_crc": 1,
            "next_hex": -1,
            "next_rect": -1,
            "next_tri":1,
        },
        "4":{
            "num_wheels":3,
            "length": 1,
            "shape": 1,
            "num_load": 1,
            "shape_load": 4,
            "next_crc": -1,
            "next_hex": -1,
            "next_rect": -1,
            "next_tri":1,
        },
    },
    "rect2rect":-1,
    "rect2tri":-1,
    "rect2hex":-1,
    "rect2circ":-1,
    "tri2tri":1,
    "tri2hex":-1,
    "tri2circ":1,
    "circ2cir":-1,
    "east":1
}
dataset['4'] = {
    "num_car": 5,
    "dif_loads": 3,
    "cars":{
        "1":{
            "num_wheels":2,
            "length": 1,
            "shape": 5,
            "num_load": 0,
            "shape_load": -1,
            "next_crc": -1,
            "next_hex": -1,
            "next_rect": -1,
            "next_tri":1,
        },
        "2":{
            "num_wheels":2,
            "length": -1,
            "shape": 8,
            "num_load": 1,
            "shape_load": 4,
            "next_crc": -1,
            "next_hex": -1,
            "next_rect": -1,
            "next_tri":1,
        },
        "3":{
            "num_wheels":2,
            "length": -1,
            "shape": 3,
            "num_load": 1,
            "shape_load": 4,
            "next_crc": -1,
            "next_hex": 1,
            "next_rect": -1,
            "next_tri":1,
        },
        "4":{
            "num_wheels":2,
            "length": -1,
            "shape": 4,
            "num_load": 1,
            "shape_load": 2,
            "next_crc": -1,
            "next_hex": -1,
            "next_rect": 1,
            "next_tri":1,
        },
        "5":{
            "num_wheels":2,
            "length": -1,
            "shape": 2,
            "num_load": 1,
            "shape_load": 3,
            "next_crc": -1,
            "next_hex": 1,
            "next_rect": -1,
            "next_tri":-1,
        }
    },
    "rect2rect":-1,
    "rect2tri":-1,
    "rect2hex":1,
    "rect2circ":-1,
    "tri2tri":1,
    "tri2hex":1,
    "tri2circ":-1,
    "circ2cir":-1,
    "east":1
}
dataset['5'] = {
    "num_car": 4,
    "dif_loads": 3,
    "cars":{
        "1":{
            "num_wheels":2,
            "length": 1,
            "shape": 5,
            "num_load": 0,
            "shape_load": -1,
            "next_crc": -1,
            "next_hex": -1,
            "next_rect": -1,
            "next_tri":1,
        },
        "2":{
            "num_wheels":2,
            "length": -1,
            "shape": 3,
            "num_load": 1,
            "shape_load": 4,
            "next_crc": -1,
            "next_hex": -1,
            "next_rect": 1,
            "next_tri":-1,
        },
        "3":{
            "num_wheels":3,
            "length": 1,
            "shape": 1,
            "num_load": 1,
            "shape_load": 3,
            "next_crc": 1,
            "next_hex": -1,
            "next_rect": -1,
            "next_tri":1,
        },
        "4":{
            "num_wheels":2,
            "length": -1,
            "shape": 1,
            "num_load": 1,
            "shape_load": 1,
            "next_crc": -1,
            "next_hex": -1,
            "next_rect": 1,
            "next_tri":-1,
        }
    },
    "rect2rect":-1,
    "rect2tri":1,
    "rect2hex":-1,
    "rect2circ":1,
    "tri2tri":-1,
    "tri2hex":-1,
    "tri2circ":-1,
    "circ2cir":-1,
    "east":1
}
dataset['6'] = {
    "num_car": 3,
    "dif_loads": 2,
    "cars":{
        "1":{
            "num_wheels":2,
            "length": 1,
            "shape": 5,
            "num_load": 0,
            "shape_load": -1,
            "next_crc": 1,
            "next_hex": -1,
            "next_rect": -1,
            "next_tri":-1,
        },
        "2":{
            "num_wheels":2,
            "length": 1,
            "shape": 1,
            "num_load": 3,
            "shape_load": 1,
            "next_crc": -1,
            "next_hex": -1,
            "next_rect": -1,
            "next_tri":1,
        },
        "3":{
            "num_wheels":2,
            "length": -1,
            "shape": 2,
            "num_load": 1,
            "shape_load": 4,
            "next_crc": 1,
            "next_hex": -1,
            "next_rect": -1,
            "next_tri":-1,
        }
    },
    "rect2rect":-1,
    "rect2tri":-1,
    "rect2hex":-1,
    "rect2circ":-1,
    "tri2tri":-1,
    "tri2hex":-1,
    "tri2circ":1,
    "circ2cir":-1,
    "east":-1
}
dataset['7'] = {
    "num_car": 4,
    "dif_loads": 2,
    "cars":{
        "1":{
            "num_wheels":2,
            "length": 1,
            "shape": 5,
            "num_load": 0,
            "shape_load": -1,
            "next_crc": 1,
            "next_hex": -1,
            "next_rect": -1,
            "next_tri":-1,
        },
        "2":{
            "num_wheels":2,
            "length": -1,
            "shape": 3,
            "num_load": 1,
            "shape_load": 1,
            "next_crc": -1,
            "next_hex": -1,
            "next_rect": -1,
            "next_tri":1,
        },
        "3":{
            "num_wheels":2,
            "length": -1,
            "shape": 2,
            "num_load": 1,
            "shape_load": 4,
            "next_crc": 1,
            "next_hex": -1,
            "next_rect": -1,
            "next_tri":-1,
        },
        "4":{
            "num_wheels":2,
            "length": 1,
            "shape": 7,
            "num_load": 0,
            "shape_load": -1,
            "next_crc": -1,
            "next_hex": -1,
            "next_rect": -1,
            "next_tri":1,
        }
    },
    "rect2rect":-1,
    "rect2tri":-1,
    "rect2hex":-1,
    "rect2circ":-1,
    "tri2tri":-1,
    "tri2hex":-1,
    "tri2circ":1,
    "circ2cir":-1,
    "east":-1
}
dataset['8'] = {
    "num_car": 3,
    "dif_loads": 2,
    "cars":{
        "1":{
            "num_wheels":2,
            "length": 1,
            "shape": 5,
            "num_load": 0,
            "shape_load": -1,
            "next_crc": -1,
            "next_hex": -1,
            "next_rect": 1,
            "next_tri":-1,
        },
        "2":{
            "num_wheels":3,
            "length": 1,
            "shape": 1,
            "num_load": 1,
            "shape_load": 3,
            "next_crc": 1,
            "next_hex": -1,
            "next_rect": -1,
            "next_tri":-1,
        },
        "3":{
            "num_wheels":2,
            "length": -1,
            "shape": 2,
            "num_load": 1,
            "shape_load": 1,
            "next_crc": -1,
            "next_hex": -1,
            "next_rect": 1,
            "next_tri":-1,
        }
    },
    "rect2rect":-1,
    "rect2tri":-1,
    "rect2hex":-1,
    "rect2circ":1,
    "tri2tri":-1,
    "tri2hex":-1,
    "tri2circ":-1,
    "circ2cir":-1,
    "east":-1
}
dataset['9'] = {
    "num_car": 5,
    "dif_loads": 2,
    "cars":{
        "1":{
            "num_wheels":2,
            "length": 1,
            "shape": 5,
            "num_load": 0,
            "shape_load": -1,
            "next_crc": 1,
            "next_hex": -1,
            "next_rect": -1,
            "next_tri":-1,
        },
        "2":{
            "num_wheels":2,
            "length": -1,
            "shape": 8,
            "num_load": 1,
            "shape_load": 1,
            "next_crc": -1,
            "next_hex": -1,
            "next_rect": 1,
            "next_tri":-1,
        },
        "3":{
            "num_wheels":3,
            "length": 1,
            "shape": 7,
            "num_load": 1,
            "shape_load": 3,
            "next_crc": 1,
            "next_hex": -1,
            "next_rect": 1,
            "next_tri":-1,
        },
        "4":{
            "num_wheels":2,
            "length": -1,
            "shape": 2,
            "num_load": 1,
            "shape_load": 3,
            "next_crc": 1,
            "next_hex": -1,
            "next_rect": 1,
            "next_tri":-1,
        },
        "5":{
            "num_wheels":2,
            "length": -1,
            "shape": 8,
            "num_load": 1,
            "shape_load": 1,
            "next_crc": -1,
            "next_hex": -1,
            "next_rect": 1,
            "next_tri":-1,
        }
    },
    "rect2rect":1,
    "rect2tri":-1,
    "rect2hex":-1,
    "rect2circ":1,
    "tri2tri":-1,
    "tri2hex":-1,
    "tri2circ":1,
    "circ2cir":-1,
    "east":-1
}
dataset['10'] = {
    "num_car": 3,
    "dif_loads": 1,
    "cars":{
        "1":{
            "num_wheels":2,
            "length": 1,
            "shape": 5,
            "num_load": 0,
            "shape_load": -1,
            "next_crc": -1,
            "next_hex": -1,
            "next_rect": 1,
            "next_tri":-1,
        },
        "2":{
            "num_wheels":2,
            "length": -1,
            "shape": 2,
            "num_load": 1,
            "shape_load": 3,
            "next_crc": -1,
            "next_hex": -1,
            "next_rect": 1,
            "next_tri":-1,
        },
        "3":{
            "num_wheels":2,
            "length": 1,
            "shape": 2,
            "num_load": 2,
            "shape_load": 3,
            "next_crc": -1,
            "next_hex": -1,
            "next_rect": 1,
            "next_tri":-1,
        }
    },
    "rect2rect":1,
    "rect2tri":-1,
    "rect2hex":-1,
    "rect2circ":-1,
    "tri2tri":-1,
    "tri2hex":-1,
    "tri2circ":1,
    "circ2cir":-1,
    "east":-1
}

# %%
import json
with open('train_dataset.josn', 'w') as fl:
    json.dump(dataset, fl)

# %% [markdown]
# # Question 2
# The same, but now with some more examples!
# I'll change the train identifier to these, to continue from the others, which will act as a complement.
# So train 11 through 14 are headed east, while trains 15 through 18 are headed west.

# %%
dataset2 = dict()
dataset2['11'] = {
    "num_car": 5,
    "dif_loads": 3,
    "cars":{
        "1":{
            "num_wheels":2,
            "length": 1,
            "shape": 5,
            "num_load": 0,
            "shape_load": -1,
            "next_crc": -1,
            "next_hex": -1,
            "next_rect": -1,
            "next_tri":-1,
        },
        "2":{
            "num_wheels":2,
            "length": 1,
            "shape": 7,
            "num_load": 0,
            "shape_load": -1,
            "next_crc": -1,
            "next_hex": -1,
            "next_rect": -1,
            "next_tri":1,
        },
        "3":{
            "num_wheels":2,
            "length": -1,
            "shape": 2,
            "num_load": 1,
            "shape_load": 4,
            "next_crc": 1,
            "next_hex": -1,
            "next_rect": -1,
            "next_tri":-1,
        },
        "4":{
            "num_wheels":2,
            "length": -1,
            "shape": 6,
            "num_load": 1,
            "shape_load": 1,
            "next_crc": -1,
            "next_hex": -1,
            "next_rect": 1,
            "next_tri":1,
        },
        "5":{
            "num_wheels":3,
            "length": 1,
            "shape": 7,
            "num_load": 1,
            "shape_load": 3,
            "next_crc": 1,
            "next_hex": -1,
            "next_rect": -1,
            "next_tri":-1,
        }
    },
    "rect2rect":-1,
    "rect2tri":-1,
    "rect2hex":-1,
    "rect2circ":1,
    "tri2tri":-1,
    "tri2hex":-1,
    "tri2circ":1,
    "circ2cir":-1,
    "east":1
}
dataset2['12'] = {
    "num_car": 4,
    "dif_loads": 3,
    "cars":{
        "1":{
            "num_wheels":2,
            "length": 1,
            "shape": 5,
            "num_load": 0,
            "shape_load": -1,
            "next_crc": -1,
            "next_hex": -1,
            "next_rect": -1,
            "next_tri":1,
        },
        "2":{
            "num_wheels":2,
            "length": -1,
            "shape": 1,
            "num_load": 1,
            "shape_load": 4,
            "next_crc": -1,
            "next_hex": -1,
            "next_rect": 1,
            "next_tri":-1,
        },
        "3":{
            "num_wheels":2,
            "length": -1,
            "shape": 2,
            "num_load": 1,
            "shape_load": 3,
            "next_crc": -1,
            "next_hex": 1,
            "next_rect": -1,
            "next_tri":1,
        },
        "4":{
            "num_wheels":2,
            "length": 1,
            "shape": 2,
            "num_load": 1,
            "shape_load": 2,
            "next_crc": -1,
            "next_hex": -1,
            "next_rect": 1,
            "next_tri":-1,
        }
    },
    "rect2rect":-1,
    "rect2tri":1,
    "rect2hex":1,
    "rect2circ":-1,
    "tri2tri":-1,
    "tri2hex":-1,
    "tri2circ":-1,
    "circ2cir":-1,
    "east":1
}
dataset2['13'] = {
    "num_car": 5,
    "dif_loads": 2,
    "cars":{
        "1":{
            "num_wheels":2,
            "length": 1,
            "shape": 5,
            "num_load": 0,
            "shape_load": -1,
            "next_crc": -1,
            "next_hex": -1,
            "next_rect": 1,
            "next_tri":-1,
        },
        "2":{
            "num_wheels":2,
            "length": -1,
            "shape": 2,
            "num_load": 1,
            "shape_load": 3,
            "next_crc": 1,
            "next_hex": -1,
            "next_rect": -1,
            "next_tri":-1,
        },
        "3":{
            "num_wheels":2,
            "length": 1,
            "shape": 1,
            "num_load": 1,
            "shape_load": 1,
            "next_crc": -1,
            "next_hex": -1,
            "next_rect": 1,
            "next_tri":-1,
        },
        "4":{
            "num_wheels":2,
            "length": -1,
            "shape": 8,
            "num_load": 1,
            "shape_load": 3,
            "next_crc": 1,
            "next_hex": -1,
            "next_rect": 1,
            "next_tri":-1,
        },
        "5":{
            "num_wheels":2,
            "length": -1,
            "shape": 9,
            "num_load": 1,
            "shape_load": 3,
            "next_crc": -1,
            "next_hex": -1,
            "next_rect": 1,
            "next_tri":-1,
        }
    },
    "rect2rect":1,
    "rect2tri":-1,
    "rect2hex":-1,
    "rect2circ":1,
    "tri2tri":-1,
    "tri2hex":-1,
    "tri2circ":-1,
    "circ2cir":-1,
    "east":1
}
dataset2['14'] = {
    "num_car": 5,
    "dif_loads": 4,
    "cars":{
        "1":{
            "num_wheels":2,
            "length": 1,
            "shape": 5,
            "num_load": 0,
            "shape_load": -1,
            "next_crc": -1,
            "next_hex": -1,
            "next_rect": -1,
            "next_tri":1,
        },
        "2":{
            "num_wheels":2,
            "length": -1,
            "shape": 2,
            "num_load": 1,
            "shape_load": 4,
            "next_crc": -1,
            "next_hex": 1,
            "next_rect": -1,
            "next_tri":-1,
        },
        "3":{
            "num_wheels":3,
            "length": 1,
            "shape": 7,
            "num_load": 1,
            "shape_load": 2,
            "next_crc": 1,
            "next_hex": -1,
            "next_rect": -1,
            "next_tri":1,
        },
        "4":{
            "num_wheels":2,
            "length": -1,
            "shape": 2,
            "num_load": 1,
            "shape_load": 1,
            "next_crc": -1,
            "next_hex": 1,
            "next_rect": 1,
            "next_tri":-1,
        },
        "5":{
            "num_wheels":2,
            "length": 1,
            "shape": 2,
            "num_load": 3,
            "shape_load": 3,
            "next_crc": 1,
            "next_hex": -1,
            "next_rect": -1,
            "next_tri":-1,
        }
    },
    "rect2rect":-1,
    "rect2tri":-1,
    "rect2hex":-1,
    "rect2circ":1,
    "tri2tri":-1,
    "tri2hex":1,
    "tri2circ":-1,
    "circ2cir":-1,
    "east":1
}
dataset2['15'] = {
    "num_car": 3,
    "dif_loads": 2,
    "cars":{
        "1":{
            "num_wheels":2,
            "length": 1,
            "shape": 5,
            "num_load": 0,
            "shape_load": -1,
            "next_crc": -1,
            "next_hex": -1,
            "next_rect": -1,
            "next_tri":1,
        },
        "2":{
            "num_wheels":2,
            "length": 1,
            "shape": 1,
            "num_load": 3,
            "shape_load": 4,
            "next_crc": -1,
            "next_hex": -1,
            "next_rect": 1,
            "next_tri":-1,
        },
        "3":{
            "num_wheels":2,
            "length": -1,
            "shape": 8,
            "num_load": 1,
            "shape_load": 3,
            "next_crc": -1,
            "next_hex": -1,
            "next_rect": -1,
            "next_tri":1,
        }
    },
    "rect2rect":-1,
    "rect2tri":1,
    "rect2hex":-1,
    "rect2circ":-1,
    "tri2tri":-1,
    "tri2hex":-1,
    "tri2circ":-1,
    "circ2cir":-1,
    "east":-1
}
dataset2['16'] = {
    "num_car": 5,
    "dif_loads": 3,
    "cars":{
        "1":{
            "num_wheels":2,
            "length": 1,
            "shape": 5,
            "num_load": 0,
            "shape_load": -1,
            "next_crc": -1,
            "next_hex": -1,
            "next_rect": 1,
            "next_tri":-1,
        },
        "2":{
            "num_wheels":2,
            "length": 1,
            "shape": 2,
            "num_load": 3,
            "shape_load": 3,
            "next_crc": 1,
            "next_hex": -1,
            "next_rect": -1,
            "next_tri":-1,
        },
        "3":{
            "num_wheels":2,
            "length": -1,
            "shape": 3,
            "num_load": 1,
            "shape_load": 1,
            "next_crc": 1,
            "next_hex": -1,
            "next_rect": 1,
            "next_tri":-1,
        },
        "4":{
            "num_wheels":2,
            "length": -1,
            "shape": 2,
            "num_load": 1,
            "shape_load": 1,
            "next_crc": 1,
            "next_hex": 1,
            "next_rect": -1,
            "next_tri":-1,
        },
        "5":{
            "num_wheels":2,
            "length": 1,
            "shape": 2,
            "num_load": 1,
            "shape_load": 2,
            "next_crc": 1,
            "next_hex": -1,
            "next_rect": -1,
            "next_tri":-1,
        }
    },
    "rect2rect":-1,
    "rect2tri":-1,
    "rect2hex":-1,
    "rect2circ":1,
    "tri2tri":-1,
    "tri2hex":-1,
    "tri2circ":-1,
    "circ2cir":1,
    "east":-1
}
dataset2['17'] = {
    "num_car": 3,
    "dif_loads": 2,
    "cars":{
        "1":{
            "num_wheels":2,
            "length": 1,
            "shape": 5,
            "num_load": 0,
            "shape_load": -1,
            "next_crc": -1,
            "next_hex": -1,
            "next_rect": 1,
            "next_tri":-1,
        },
        "2":{
            "num_wheels":3,
            "length": 1,
            "shape": 2,
            "num_load": 3,
            "shape_load": 3,
            "next_crc": -1,
            "next_hex": -1,
            "next_rect": -1,
            "next_tri":1,
        },
        "3":{
            "num_wheels":2,
            "length": -1,
            "shape": 2,
            "num_load": 1,
            "shape_load": 4,
            "next_crc": -1,
            "next_hex": -1,
            "next_rect": 1,
            "next_tri":-1,
        }
    },
    "rect2rect":-1,
    "rect2tri":1,
    "rect2hex":-1,
    "rect2circ":-1,
    "tri2tri":-1,
    "tri2hex":-1,
    "tri2circ":-1,
    "circ2cir":-1,
    "east":-1
}
dataset2['18'] = {
    "num_car": 5,
    "dif_loads": 2,
    "cars":{
        "1":{
            "num_wheels":2,
            "length": 1,
            "shape": 5,
            "num_load": 0,
            "shape_load": -1,
            "next_crc": -1,
            "next_hex": -1,
            "next_rect": -1,
            "next_tri":1,
        },
        "2":{
            "num_wheels":2,
            "length": -1,
            "shape": 2,
            "num_load": 1,
            "shape_load": 4,
            "next_crc": -1,
            "next_hex": -1,
            "next_rect": -1,
            "next_tri":-1,
        },
        "3":{
            "num_wheels":2,
            "length": 1,
            "shape": 2,
            "num_load": 0,
            "shape_load": -1,
            "next_crc": -1,
            "next_hex": -1,
            "next_rect": 1,
            "next_tri":1,
        },
        "4":{
            "num_wheels":2,
            "length": 1,
            "shape": 1,
            "num_load": 3,
            "shape_load": 3,
            "next_crc": -1,
            "next_hex": -1,
            "next_rect": 1,
            "next_tri":-1,
        },
        "5":{
            "num_wheels":2,
            "length": 1,
            "shape": 1,
            "num_load": 3,
            "shape_load": 3,
            "next_crc": -1,
            "next_hex": -1,
            "next_rect": 1,
            "next_tri":-1,
        }
    },
    "rect2rect":1,
    "rect2tri":-1,
    "rect2hex":-1,
    "rect2circ":-1,
    "tri2tri":-1,
    "tri2hex":-1,
    "tri2circ":-1,
    "circ2cir":-1,
    "east":-1
}

# %%
with open("train_dataset2.json", 'w') as fl:
    json.dump(dataset2, fl)

# %% [markdown]
# ## Playground

# %%
import pandas as pd

# %%
car_df = pd.DataFrame()
train_df = pd.DataFrame()
for train_id in dataset.keys():
    train = dataset[train_id]
    train['train_id'] = train_id
    for car_id in train['cars']:
        train['cars'][car_id]['car_id'] = car_id
        train['cars'][car_id]['train_id'] = train_id
    car_df = pd.concat([car_df, pd.DataFrame(train['cars']).T])
    tmp = train.copy()
    tmp.pop('cars')
    train_df = pd.concat([train_df, pd.DataFrame(train, index=[train_id])])
train_df = train_df.drop('cars', axis=1)

# %%
train_df.drop('cars', axis=1)
# Out:
#     num_car  dif_loads  rect2rect  rect2tri  rect2hex  rect2circ  tri2tri  \
# 1         5          4         -1         1        -1         -1       -1
# 2         4          3         -1         1        -1          1       -1
# 3         4          2         -1        -1        -1         -1        1
# 4         5          3         -1        -1         1         -1        1
# 5         4          3         -1         1        -1          1       -1
# 6         3          2         -1        -1        -1         -1       -1
# 7         4          2         -1        -1        -1         -1       -1
# 8         3          2         -1        -1        -1          1       -1
# 9         5          2          1        -1        -1          1       -1
# 10        3          1          1        -1        -1         -1       -1
#
#     tri2hex  tri2circ  circ2cir  east train_id
# 1         1        -1        -1     1        1
# 2        -1        -1        -1     1        2
# ...

# %%
pd.DataFrame(train, index=[train_id])
# Out:
#    num_car  dif_loads  rect2rect  rect2tri  rect2hex  rect2circ  tri2tri  \
# 1        5          4         -1         1        -1         -1       -1
#
#    tri2hex  tri2circ  circ2cir  east train_id
# 1        1        -1        -1     1        1

# %%
pd.DataFrame.from_dict(train['cars']).T
# Out:
#   num_wheels length shape num_load shape_load car_id
# 1          2      1     5        0         -1      1
# 2          2      1     2        3          2      2
# 3          2     -1     9        1          4      3
# 4          3      1     2        1          2      4
# 5          2     -1     2        1          1      5

# %%
pd.concat([pd.DataFrame.from_dict(train).drop('cars',axis=1).iloc[0], pd.DataFrame.from_dict(train).drop('cars',axis=1).iloc[0]])
# Out:
# num_car       3
# dif_loads     1
# rect2rect     1
# rect2tri     -1
# rect2hex     -1
# rect2circ    -1
# tri2tri      -1
# tri2hex      -1
# tri2circ      1
# circ2cir     -1
# east         -1
# train_id     10
# num_car       3
# dif_loads     1
# rect2rect     1
# rect2tri     -1
# rect2hex     -1
# rect2circ    -1
# tri2tri      -1
# tri2hex      -1
# tri2circ      1
# circ2cir     -1
# east         -1
# train_id     10
# Name: 1, dtype: object
